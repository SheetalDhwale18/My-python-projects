# %%
import random
import pyttsx3






def choose_option():

        engine.say("Choose Rock,Paper or Scissors")
        engine.runAndWait()
        user_choice=input("\nChoose Rock,Paper or Scissors:")

        if user_choice in ["rock","Rock","r","R"]:
            user_choice="r"
            return user_choice

        elif user_choice in ["Paper","paper","p","P"]:
            user_choice="p"
            return user_choice


        elif user_choice in ["scissors","Scissors","s","S"]:
            user_choice="s"
            return user_choice
    
        else:
            print("sorry! i didn't get it! try again.")
            engine.say("sorry! i didn't get it! try again.")
            engine.runAndWait()
            choose_option()
            return user_choice

# %%
def computer_option():
    comp_choice=random.randint(1,3)
    if comp_choice==1:
        comp_choice="r"
    elif comp_choice==2:
        comp_choice="p"
    else:
        comp_choice='s'
    return comp_choice

# %%
engine=pyttsx3.init()
print("\nhello wanna play a Rock , Paper ,Scissors game?")
engine.say("hello! wanna play a Rock Paper and Scissors game?")
engine.say("enter your name")
engine.runAndWait()
name=input("enter your name:")
try:
    engine.say("enter your gender 1 for female and 0 for male")
    engine.runAndWait()
    gender=int(input("enter gender:[1 for female and 0 for male]"))
    if gender==1:
        s=1
    elif gender==0: 
        s=0
    else:
        print("this is not valid choice!")
        engine.say(" sorry! i am considering your gender as female because you enterd invalid input")
        engine.runAndWait()
except ValueError as e:
    print(e)
    engine.say("you have exception! you enterd your gender in wrong way .sorry i am going to consider your gender as female.")

voices=engine.getProperty('voices')
engine.setProperty('voice',voices[s].id)
rate = engine.getProperty('rate')               
engine.setProperty('rate', 150)  
engine.say("hello"+ name + "welcome to this game!")
print("lets satrt!")
engine.say("lets start!")
print("good luck!")  
engine.say("good luck!")
engine.runAndWait()
while True:
    player_score=0
    comp_score=0
    for i in range(1,10):
        user_choice=choose_option()
        comp_choice=computer_option()

        if user_choice=='r':
            if comp_choice=="r":
                print("player choose :rock ")
                print("computer choose :rock")
                print("this is tied!")
                engine.say("player choose :rock ")
                engine.say("computer choose :rock")
                engine.say("this is tied!")
                engine.runAndWait()
            elif comp_choice=="p":
                print("player choose :rock")
                engine.say("player choose :rock")
                print("computer choose :paper")
                engine.say("computer choose :paper")
                print("you lose paper covers rock")
                engine.say("you lose paper covers rock")
                engine.runAndWait()
                comp_score+=1
            elif comp_choice=="s":
                print("player choose :rock")
                engine.say("player choose :rock")
                print("computer choose :scissors") 
                engine.say("computer choose :scissors")
                print("you win rock beats scissor")
                engine.say("you win rock beats scissor")
                engine.runAndWait()
                player_score+=1

        elif user_choice=='p':
            if comp_choice=="r":
                print("player choose :paper ")
                engine.say("player choose :paper ")
                print("computer choose :rock ")
                engine.say("computer choose :rock ")
                print( "you win , paper cover rock..")
                engine.say("you win , paper cover rock..")
                engine.runAndWait()
                player_score+=1
            if comp_choice=="p":
                print("player choose paper") 
                engine.say("player choose paper")
                print(" computer choose :paper")
                engine.say("computer choose :paper")
                print("so this is tied!")
                engine.say("so this is tied!")
                engine.runAndWait()
            if comp_choice=="s":
                print("player choose :paper")
                engine.say("player choose :paper")
                print("computer choose :scissors")
                engine.say("computer choose :scissors")
                print("you lose , scissor cuts paper")
                engine.say("you lose , scissor cuts paper")
                engine.runAndWait()
                comp_score+=1

        elif user_choice=='s':
            if comp_choice=='r':
                print("you choose :scissor")
                engine.say("you choose :scissor")
                print("computer choose :rock")
                engine.say("computer choose :rock")
                print("you lose, rock beats scissor")
                engine.say("you lose, rock beats scissor")
                engine.runAndWait()
                comp_score+=1
                
            if comp_choice=="p":
                print("player choose :scissor")  
                engine.say("player choose :scissor")
                print("computer choose :paper")
                engine.say("computer choose :paper")
                print("you win scissor cuts paper")
                engine.say("you win scissor cuts paper")
                engine.runAndWait()
                player_score+=1
            if comp_choice=="s":
                print("player choose :scissor")  
                engine.say("player choose :scissor")
                print("computer choose :scissor ")
                engine.say("computer choose :scissor ")
                print("so it is tied")
                engine.say("so it is tied")
                engine.runAndWait()
        print("")
        print("the player score   is:",str(player_score))
        engine.say("the player score after this round is "+str(player_score))
        print("the computer score  is:",str(comp_score))
        engine.say("the computer score after this round is "+str(comp_score))
        engine.runAndWait()         
        if player_score==3 or comp_score==3:
            break
        else:
            continue
    
    engine.say("\nthe game is over let's see the final score ")
    print("\nFinal score :")
    print("the player score in this game  is :",str(player_score))
    engine.say("your score in this game is "+str(player_score))
    print("the computer score in this game  is :",str(comp_score))
    engine.say("the computer score in this game is "+str(comp_score))
    engine.runAndWait()
    if player_score<comp_score:
        print("oops! you lose the game , better luck next time.")
        engine.say("oops!"+name+ "you lose the game , better luck next time.")
        engine.runAndWait()
        engine.say("Do you want to play it again? press y if yes or n if no")
        engine.runAndWait()
        choice=input("Do you want to play again?(y/n)")

        if choice=="y":
            print("let's play it again, good luck!")
            engine.say("let's play it again, good luck!")
            engine.runAndWait()
            continue
        elif choice=="n":
            print("thank you see you again!")
            engine.say("thank you see you again!")
            engine.runAndWait()
            break

    elif player_score==comp_score:
        print("the game is tied!!")
        engine.say("the game is tied!!")
        engine.runAndWait()
        engine.say("Do you want to play it again? press y if yes or n if no")
        engine.runAndWait()
        choice=input("Do you want to play again?(y/n)")

        if choice=="y":
            print("let's play it again, good luck!")
            engine.say("let's play it again, good luck!")
            engine.runAndWait()
            continue
        elif choice=="n":
            print("thank you see you again!")
            engine.say("thank you see you again!")
            engine.runAndWait()
            break

    else:
        print("congratulations! you win the game.")
        engine.say("congratulations!"+name+"you win the game")
        engine.runAndWait()
        engine.say("Do you want to play it again? press y if yes or n if no")
        engine.runAndWait()
        choice=input("Do you want to play again?(y/n)")

        if choice=="y":
            print("let's play it again, good luck!")
            engine.say("let's play it again, good luck!")
            engine.runAndWait()
            continue
        elif choice=="n":
            print("thank you see you again!")
            engine.say("thank you see you again!")
            engine.runAndWait()
            break
# Out:
# hello wanna play a Rock , Paper ,Scissors game?
# enter your name:sheetal
# enter gender:[1 for female and 0 for male]1
# lets satrt!
# good luck!
#
# Choose Rock,Paper or Scissors:r
# player choose :rock
# computer choose :scissors
# you win rock beats scissor
#
# the player score   is: 1
# the computer score  is: 0
#
# Choose Rock,Paper or Scissors:s
# player choose :scissor
# computer choose :paper
# you win scissor cuts paper
#
# the player score   is: 2
# the computer score  is: 0
#
# Choose Rock,Paper or Scissors:p
# player choose :paper
# computer choose :scissors
# you lose , scissor cuts paper
#
# the player score   is: 2
# the computer score  is: 1
#
# Choose Rock,Paper or Scissors:p
# player choose :paper
# computer choose :rock
# you win , paper cover rock..
#
# the player score   is: 3
# the computer score  is: 1
#
# Final score :
# the player score in this game  is : 3
# the computer score in this game  is : 1
# congratulations! you win the game.
# ...
